# %%
import shioaji as sj

api = sj.Shioaji()
accounts = api.login("J120420374", "celia5818")
api.activate_ca(
    ca_path="c:/eleader/ca/Sinopac.pfx",
    ca_passwd="J120420374",
    person_id="J120420374",
)
# Out:
# Response Code: 0 | Event Code: 0 | Info: host '203.66.91.161:80', hostname '203.66.91.161:80' IP 203.66.91.161:80 (host 1 of 1) (host connection attempt 1 of 1) (total connection attempt 1 of 1) | Event: Session up
# True
# Response Code: 0 | Event Code: 12 | Info: solClient.c:12194                    (00000dfc) Session '(c0,s1)_sinopac' keep-alive on tcp_TxRx detected session down, client name 'PYAPI/J120420374/1223/074024/525064/114.137.103.170', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203 | Event: Session reconnecting
# Session Down.
# Response Code: 0 | Event Code: 1 | Info: solClientOS.c:4220                   (00000dfc) TCP connection failure for fd 1368, error = No route to host (10065) | Event: Session down
