# %%
# !python -m pip install shioaji

# %%
import shioaji as sj
# ---- Formal Login
api = sj.Shioaji()
accounts = api.login(
    "J120420374", 
    "celia5818",
    contracts_timeout=10000
)

api.activate_ca(
    #ca_path="C:/ekey/551/J120420374/S/Sinopac.pfx",
    ca_path="c:/eleader/ca/Sinopac.pfx",
    ca_passwd="J120420374",
    person_id="J120420374",
)

contract_dhf = api.Contracts.Futures.DHF['DHF202201'] #鴻海期貨202201 (=DHFA2)

# futures order
order1 = api.Order(
    action=sj.constant.Action.Buy,
    price=104.5,
    quantity=1,
    price_type=sj.constant.FuturesPriceType.LMT,
    order_type=sj.constant.FuturesOrderType.ROD, 
    octype=sj.constant.FuturesOCType.Auto,
    account=api.futopt_account
)

trade = api.place_order(contract_dhf, order1)
trade
# Out:
# Response Code: 0 | Event Code: 0 | Info: host '203.66.91.161:80', hostname '203.66.91.161:80' IP 203.66.91.161:80 (host 1 of 1) (host connection attempt 1 of 1) (total connection attempt 1 of 1) | Event: Session up
# Trade(contract=Future(code='DHFA2', symbol='DHF202201', name='鴻海期貨01', category='DHF', delivery_month='202201', delivery_date='2022/01/19', underlying_kind='S', underlying_code='2317', unit=1, limit_up=116.0, limit_down=95.0, reference=105.5, update_date='2021/12/30'), order=Order(action=<Action.Buy: 'Buy'>, price=104.5, quantity=1, id='0df7bbff', seqno='931312', account=Account(account_type=<AccountType.Future: 'F'>, person_id='J120420374', broker_id='F002000', account_id='1641626', signed=True), price_type=<StockPriceType.LMT: 'LMT'>, order_type=<FuturesOrderType.ROD: 'ROD'>), status=OrderStatus(id='0df7bbff', status=<Status.PendingSubmit: 'PendingSubmit'>, status_code='    ', order_datetime=datetime.datetime(2021, 12, 30, 12, 38, 41), deals=[]))
# OrderState.FOrder {'operation': {'op_type': 'New', 'op_code': '00', 'op_msg': ''}, 'order': {'id': '0df7bbff', 'seqno': '931312', 'ordno': 'tn0R1', 'account': {'account_type': 'F', 'person_id': '', 'broker_id': 'F002000', 'account_id': '1641626', 'signed': True}, 'action': 'Buy', 'price': 104.5, 'quantity': 1, 'order_type': 'ROD', 'market_type': 'Day', 'oc_type': 'New', 'subaccount': ''}, 'status': {'id': '0df7bbff', 'exchange_ts': 1640839122, 'modified_price': 0.0, 'cancel_quantity': 0, 'order_quantity': 1}, 'contract': {'security_type': 'FUT', 'code': 'DHF', 'exchange': 'TIM', 'delivery_month': '202201', 'delivery_date': '', 'strike_price': 0.0, 'option_right': 'Future'}}
# OrderState.FDeal {'trade_id': '0df7bbff', 'seqno': '931312', 'ordno': 'tn0R1H1Y', 'exchange_seq': 'b0012310', 'broker_id': 'F002000', 'account_id': '1641626', 'action': 'Buy', 'code': 'DHF', 'price': 104.5, 'quantity': 1, 'subaccount': '', 'security_type': 'FUT', 'delivery_month': '202201', 'strike_price': 0.0, 'option_right': 'Future', 'market_type': 'Day', 'ts': 1640839122}
# OrderState.FOrder {'operation': {'op_type': 'New', 'op_code': '00', 'op_msg': ''}, 'order': {'id': '13258e98', 'seqno': '750377', 'ordno': 'tn0RG', 'account': {'account_type': 'F', 'person_id': '', 'broker_id': 'F002000', 'account_id': '1641626', 'signed': True}, 'action': 'Sell', 'price': 105.0, 'quantity': 1, 'order_type': 'ROD', 'market_type': 'Day', 'oc_type': 'Cover', 'subaccount': ''}, 'status': {'id': '13258e98', 'exchange_ts': 1640839357, 'modified_price': 0.0, 'cancel_quantity': 0, 'order_quantity': 1}, 'contract': {'security_type': 'FUT', 'code': 'DHF', 'exchange': 'TIM', 'delivery_month': '202201', 'delivery_date': '', 'strike_price': 0.0, 'option_right': 'Future'}}
# Response Code: 0 | Event Code: 12 | Info: solClient.c:12194                    (00002ea4) Session '(c16,s1)_sinopac' keep-alive on tcp_TxRx detected session down, client name 'PYAPI/J120420374/1230/043806/311307/114.137.180.28', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203 | Event: Session reconnecting
# Session Down.
# Response Code: 0 | Event Code: 1 | Info: solClientOS.c:4220                   (00002ea4) TCP connection failure for fd 7404, error = No route to host (10065) | Event: Session down

# %%
import shioaji as sj

api = sj.Shioaji()
accounts = api.login(
    "J120420374", 
    "celia5818",
    contracts_timeout=10000
)

api.activate_ca(
    ca_path="c:/eleader/ca/Sinopac.pfx",
    ca_passwd="J120420374",
    person_id="J120420374",
)

contract = api.Contracts.Futures.TXF.TXF202201

order = api.Order(action=sj.constant.Action.Buy,
                  price=17900,
                  quantity=1,
                  price_type=sj.constant.StockPriceType.LMT,
                  order_type=sj.constant.FuturesOrderType.ROD, 
                  octype=sj.constant.FuturesOCType.Auto,
                  account=api.futopt_account)

trade = api.place_order(contract, order)
trade
# Out:
# Response Code: 0 | Event Code: 0 | Info: host '203.66.91.161:80', hostname '203.66.91.161:80' IP 203.66.91.161:80 (host 1 of 1) (host connection attempt 1 of 1) (total connection attempt 1 of 1) | Event: Session up
# Trade(contract=Future(code='TXFA2', symbol='TXF202201', name='臺股期貨01', category='TXF', delivery_month='202201', delivery_date='2022/01/19', underlying_kind='I', unit=1, limit_up=20101.0, limit_down=16447.0, reference=18274.0, update_date='2021/12/30'), order=Order(action=<Action.Buy: 'Buy'>, price=17900, quantity=1, account=FutureAccount(person_id='J120420374', broker_id='F002000', account_id='1641626', username='黃瑞柳'), price_type=<StockPriceType.LMT: 'LMT'>, order_type=<FuturesOrderType.ROD: 'ROD'>), status=OrderStatus(status=<Status.Failed: 'Failed'>))

# %%
import shioaji as sj
# ---- Formal Login
api = sj.Shioaji(simulation=True)
accounts = api.login("PAPIUSER01", "2222", contracts_timeout=10000)

contract_dhf = api.Contracts.Futures.DHF['DHF202201'] #鴻海期貨202201 (=DHFA2)

# futures order
order1 = api.Order(
    action=sj.constant.Action.Buy,
    price=104.5,
    quantity=1,
    price_type=sj.constant.StockPriceType.LMT,
    order_type=sj.constant.FuturesOrderType.ROD, 
    octype=sj.constant.FuturesOCType.Auto,
    account=api.futopt_account
)

trade = api.place_order(contract_dhf, order1)
trade
# Out:
# Response Code: 0 | Event Code: 0 | Info: host '218.32.76.102:80', hostname '218.32.76.102:80' IP 218.32.76.102:80 (host 1 of 1) (host connection attempt 1 of 1) (total connection attempt 1 of 1) | Event: Session up
# Trade(contract=Future(code='DHFA2', symbol='DHF202201', name='鴻海期貨01', category='DHF', delivery_month='202201', delivery_date='2022/01/19', underlying_kind='S', underlying_code='2317', unit=1, limit_up=116.0, limit_down=95.0, reference=105.5, update_date='2021/12/30'), order=Order(action=<Action.Buy: 'Buy'>, price=104.5, quantity=1, id='8f1dc14f', seqno='175302', account=Account(account_type=<AccountType.Future: 'F'>, person_id='QBCCAIGJBJ', broker_id='F002000', account_id='9100020', signed=True), price_type=<StockPriceType.LMT: 'LMT'>, order_type=<FuturesOrderType.ROD: 'ROD'>), status=OrderStatus(id='8f1dc14f', status=<Status.PendingSubmit: 'PendingSubmit'>, status_code='    ', order_datetime=datetime.datetime(2021, 12, 30, 12, 23, 56), deals=[]))

# %%
import shioaji as sj

api = sj.Shioaji()
accounts = api.login(
    "J120420374", 
    "celia5818",
    contracts_timeout=10000
)

api.activate_ca(
    ca_path="c:/eleader/ca/Sinopac.pfx",
    ca_passwd="J120420374",
    person_id="J120420374",
)

contract_2317 = api.Contracts.Stocks["2317"]

order = api.Order(
    price=103.5, 
    quantity=1, 
    action=sj.constant.Action.Buy, 
    price_type=sj.constant.StockPriceType.LMT, 
    order_type=sj.constant.TFTOrderType.ROD, 
    order_lot=sj.constant.TFTStockOrderLot.Common, 
    account=api.stock_account
)

trade = api.place_order(contract_2317, order)
trade
# Out:
# Response Code: 0 | Event Code: 0 | Info: host '203.66.91.161:80', hostname '203.66.91.161:80' IP 203.66.91.161:80 (host 1 of 1) (host connection attempt 1 of 1) (total connection attempt 1 of 1) | Event: Session up
# Trade(contract=Stock(exchange=<Exchange.TSE: 'TSE'>, code='2317', symbol='TSE2317', name='鴻海', category='31', unit=1000, limit_up=115.5, limit_down=94.5, reference=105.0, update_date='2021/12/30', margin_trading_balance=881, short_selling_balance=277, day_trade=<DayTrade.Yes: 'Yes'>), order=Order(action=<Action.Buy: 'Buy'>, price=103.5, quantity=1, id='185489d6', seqno='361648', ordno='XE402', account=Account(account_type=<AccountType.Stock: 'S'>, person_id='J120420374', broker_id='9A97', account_id='0296637', signed=True), price_type=<StockPriceType.LMT: 'LMT'>, order_type=<FuturesOrderType.ROD: 'ROD'>), status=OrderStatus(id='185489d6', status=<Status.PendingSubmit: 'PendingSubmit'>, status_code='0', order_datetime=datetime.datetime(2021, 12, 30, 11, 57, 49), deals=[]))
# OrderState.TFTOrderOrderState.TFTOrder {'operation': {'op_type': 'New', 'op_code': '00', 'op_msg': ''}, 'order': {'id': '185489d6', 'seqno': '361648', 'ordno': 'XE402', 'account': {'account_type': 'S', 'person_id': '', 'broker_id': '9A97', 'account_id': '0296637', 'signed': True}, 'action': 'Buy', 'price': 103.5, 'quantity': 1, 'order_type': 'ROD', 'order_cond': 'Cash', 'order_lot': 'Common', 'price_type': 'LMT'}, 'status': {'id': '185489d6', 'exchange_ts': 1640836669, 'modified_price': 0.0, 'cancel_quantity': 0, 'order_quantity': 1}, 'contract': {'security_type': 'STK', 'exchange': 'TSE', 'code': '2317', 'symbol': '', 'name': '', 'currency': 'TWD'}}
#  {'operation': {'op_type': 'New', 'op_code': '00', 'op_msg': ''}, 'order': {'id': '185489d6', 'seqno': '361648', 'ordno': 'XE402', 'account': {'account_type': 'S', 'person_id': '', 'broker_id': '9A97', 'account_id': '0296637', 'signed': True}, 'action': 'Buy', 'price': 103.5, 'quantity': 1, 'order_type': 'ROD', 'order_cond': 'Cash', 'order_lot': 'Common', 'price_type': 'LMT'}, 'status': {'id': '185489d6', 'exchange_ts': 1640836669, 'modified_price': 0.0, 'cancel_quantity': 0, 'order_quantity': 1}, 'contract': {'security_type': 'STK', 'exchange': 'TSE', 'code': '2317', 'symbol': '', 'name': '', 'currency': 'TWD'}}
